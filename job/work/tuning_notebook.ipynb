# %%
import os
import sys
current_wd = os.getcwd()
linux_compat = current_wd.replace("\\", "/")
project_folder = linux_compat.replace("/job/work", "")
os.chdir(project_folder)

# %%
from magic_job import validate_datafolder, get_data
from creation import create_dataset
from prediction import Xy_split
from set_up.league_data import seasons
import pandas as pd
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import (
    GradientBoostingClassifier,
    RandomForestClassifier,
    AdaBoostClassifier,
)
from sklearn.model_selection import GridSearchCV
# Out:
# INFO:root:Import completed

# %%
estimators = {
    # "lda":{
    #     "model": LinearDiscriminantAnalysis(),
    #     "parameters": {"solver": ["svd"]},
    # },
    # "knn":{
    #     "model": KNeighborsClassifier(),
    #     "parameters": {"n_neighbors": np.arange(1, 298, 11)},
    # },
    "gb":{
        "model": GradientBoostingClassifier(),
        "parameters": {
            "n_estimators": [50, 100, 150],
            "learning_rate": [0.1, 0.3],
            "max_depth": [3, 5],
            "subsample": [0.75, 1.0],
            "max_features": [1.0, 0.75],
            "random_state": [66],
        },
    },
    "rf": {
        "model": RandomForestClassifier(),
        "parameters": {
            "n_estimators": [100],
            "max_depth": [None, 3, 5],
            "max_features": ["sqrt", 1.0],
            "random_state": [66],
        },
    },
    "ada": {
        "model": AdaBoostClassifier(),
        "parameters": {
            "n_estimators": [50, 100, 150],
            "algorithm": ["SAMME"],
            "random_state": [66],
        },
    }
}

# %%
def feature_combination(df):
    feature_set = []
    cols = ['giornata', 
            'anno', 
            'posizione_casa',
            'posizione_trasferta',
            'gol_fatti_casa', 
            'gol_fatti_trasferta', 
             'squadra']
    feature_set.append(cols)
    for t in range(1, 6):
        cols += [
            f"gol_fatti_{t}_casa", 
            f"gol_fatti_{t}_trasferta",
            f"gol_subiti_{t}_casa",
            f"gol_subiti_{t}_trasferta",
            f"esito_{t}_casa",
            f"esito_{t}_trasferta",
        ]
        feature_set.append(cols)
    return feature_set

# %%
df.columns
# Out:
# Index(['giornata', 'anno', 'gol_fatti_casa', 'posizione_casa',
#        'gol_fatti_1_casa', 'gol_subiti_1_casa', 'esito_1_casa',
#        'gol_fatti_2_casa', 'gol_subiti_2_casa', 'esito_2_casa',
#        'gol_fatti_3_casa', 'gol_subiti_3_casa', 'esito_3_casa',
#        'gol_fatti_4_casa', 'gol_subiti_4_casa', 'esito_4_casa',
#        'gol_fatti_5_casa', 'gol_subiti_5_casa', 'esito_5_casa',
#        'gol_fatti_trasferta', 'posizione_trasferta', 'gol_fatti_1_trasferta',
#        'gol_subiti_1_trasferta', 'esito_1_trasferta', 'gol_fatti_2_trasferta',
#        'gol_subiti_2_trasferta', 'esito_2_trasferta', 'gol_fatti_3_trasferta',
#        'gol_subiti_3_trasferta', 'esito_3_trasferta', 'gol_fatti_4_trasferta',
#        'gol_subiti_4_trasferta', 'esito_4_trasferta', 'gol_fatti_5_trasferta',
#        'gol_subiti_5_trasferta', 'esito_5_trasferta', 'squadra'],
#       dtype='object')

# %%
def tune_model(X, y, target):
    scores = features_weights = pd.DataFrame()
    for algorithm, metadata in estimators.items():
        gscv = GridSearchCV(
            estimator=metadata["model"],
            param_grid=metadata["parameters"],
            scoring="accuracy",
            cv=4,
            verbose=1,
            n_jobs=2,
        )
        gscv.fit(X, y)
        gscv.best_estimator_.feature_importances_
        report = pd.DataFrame(gscv.cv_results_)
        report = report[[
            "params", 
            "mean_test_score",
            "std_test_score",
        ]]
        report["estimator"] = algorithm
        scores = pd.concat([scores, report], ignore_index=True)

        best_est = gscv.best_estimator_
        feature_importances = best_est.feature_importances_
        feature_names = best_est.feature_names_in_
        features = pd.DataFrame(feature_importances, index=feature_names, columns=[algorithm])
        features_weights = pd.concat([features_weights, features], axis=1)
    return scores, features_weights

# %%
validate_datafolder(seasons)
df = get_data(seasons)
df = create_dataset(df)
df.groupby('anno').giornata.count()
# Out:
# INFO:root:Scraping from SkySport: season 2023
# anno
# 2019    330
# 2020    330
# 2021    330
# 2022    330
# Name: giornata, dtype: int64

# %% [markdown]
# ### Gf

# %%
X, y = Xy_split(df, "GG-NG")
scores, features = tune_model(X, y, "Gf")
# Out:
# GG-NG
# Fitting 4 folds for each of 48 candidates, totalling 192 fits
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# Fitting 4 folds for each of 3 candidates, totalling 12 fits

# %%
features.mean(axis=1).sort_values()
# Out:
# gol_subiti_2_trasferta    0.020578
# gol_subiti_5_trasferta    0.020732
# gol_fatti_5_casa          0.021560
# gol_subiti_4_trasferta    0.022679
# gol_fatti_1_casa          0.023196
# gol_fatti_4_casa          0.024880
# gol_subiti_3_trasferta    0.025571
# gol_subiti_3_casa         0.026199
# gol_fatti_2_trasferta     0.028468
# gol_fatti_4_trasferta     0.028977
# gol_subiti_4_casa         0.030022
# gol_subiti_1_trasferta    0.031332
# gol_fatti_2_casa          0.031535
# gol_subiti_2_casa         0.033821
# gol_subiti_5_casa         0.036875
# gol_subiti_1_casa         0.037388
# gol_fatti_3_trasferta     0.040636
# gol_fatti_5_trasferta     0.041322
# gol_fatti_1_trasferta     0.043716
# posizione_trasferta       0.054183
# gol_fatti_3_casa          0.072949
# anno                      0.082766
# posizione_casa            0.083369
# giornata                  0.137246
# dtype: float64

# %%
scores.sort_values(by="rank", ascending=False)
# Out:
#                                                params  mean_test_score  \
# 50  {'max_depth': 3, 'max_features': 'sqrt', 'n_es...         0.553788
# 51  {'max_depth': 3, 'max_features': 1.0, 'n_estim...         0.546970
# 52  {'max_depth': 5, 'max_features': 'sqrt', 'n_es...         0.540152
# 56  {'algorithm': 'SAMME', 'n_estimators': 150, 'r...         0.528788
# 55  {'algorithm': 'SAMME', 'n_estimators': 100, 'r...         0.528788
# 48  {'max_depth': None, 'max_features': 'sqrt', 'n...         0.528788
# 54  {'algorithm': 'SAMME', 'n_estimators': 50, 'ra...         0.528030
# 53  {'max_depth': 5, 'max_features': 1.0, 'n_estim...         0.521212
# 12  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.509091
# 1   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.507576
# 49  {'max_depth': None, 'max_features': 1.0, 'n_es...         0.501515
# 14  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.500000
# 0   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.494697
# 16  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.494697
# 3   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.493939
# 43  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.493182
# 41  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.490152
# 18  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.488636
# 36  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.485606
# 46  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.484848
# 20  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.484848
# 2   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.484091
# 22  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.484091
# 19  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.484091
# 24  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.483333
# 4   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.483333
# 7   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.481061
# 32  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.481061
# 34  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.480303
# 13  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.479545
# 6   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.478788
# 44  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.478030
# 30  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.477273
# 17  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.477273
# 5   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.476515
# 39  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.476515
# 21  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.475000
# 45  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.475000
# 25  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.475000
# 38  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.474242
# 8   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.474242
# 26  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.473485
# 47  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.471212
# 42  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.471212
# 40  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.469697
# 23  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.469697
# 15  {'learning_rate': 0.1, 'max_depth': 5, 'max_fe...         0.468939
# 29  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.467424
# 37  {'learning_rate': 0.3, 'max_depth': 5, 'max_fe...         0.464394
# 9   {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.464394
# 28  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.463636
# 27  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.462879
# 10  {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.462879
# 33  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.459848
# 11  {'learning_rate': 0.1, 'max_depth': 3, 'max_fe...         0.457576
# 35  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.456061
# 31  {'learning_rate': 0.3, 'max_depth': 3, 'max_fe...         0.453030
#
#     std_test_score estimator  rank
# 50        0.032804        rf  57.0
# 51        0.036772        rf  56.0
# 52        0.033083        rf  55.0
# 56        0.044768       ada  54.0
# 55        0.046429       ada  53.0
# 48        0.039131        rf  52.0
# 54        0.033359       ada  51.0
# 53        0.042801        rf  50.0
# 12        0.046994        gb  49.0
# 1         0.048603        gb  48.0
# 49        0.043625        rf  47.0
# 14        0.046602        gb  46.0
# 0         0.047353        gb  45.0
# 16        0.049994        gb  44.0
# 3         0.050298        gb  43.0
# 43        0.050451        gb  42.0
# 41        0.058930        gb  41.0
# 18        0.056423        gb  40.0
# 36        0.037932        gb  39.0
# 46        0.058092        gb  38.0
# 20        0.058525        gb  37.0
# 2         0.053542        gb  36.0
# 22        0.058461        gb  35.0
# 19        0.052546        gb  34.0
# 24        0.053547        gb  33.0
# 4         0.050775        gb  32.0
# 7         0.061746        gb  31.0
# 32        0.035428        gb  30.0
# 34        0.052069        gb  29.0
# 13        0.056341        gb  28.0
# 6         0.062581        gb  27.0
# 44        0.049440        gb  26.0
# 30        0.039423        gb  25.0
# 17        0.058072        gb  24.0
# 5         0.057351        gb  23.0
# 39        0.062559        gb  22.0
# 21        0.056949        gb  21.0
# 45        0.059896        gb  20.0
# 25        0.061597        gb  19.0
# 38        0.040740        gb  18.0
# 8         0.060093        gb  17.0
# 26        0.046915        gb  16.0
# 47        0.063906        gb  15.0
# 42        0.052333        gb  14.0
# 40        0.049931        gb  13.0
# 23        0.057775        gb  12.0
# 15        0.062632        gb  11.0
# 29        0.067228        gb  10.0
# 37        0.068077        gb   9.0
# 9         0.066817        gb   8.0
# 28        0.054923        gb   7.0
# 27        0.069081        gb   6.0
# 10        0.068312        gb   5.0
# 33        0.073211        gb   4.0
# 11        0.068835        gb   3.0
# 35        0.073434        gb   2.0
# 31        0.071083        gb   1.0
